# %% [markdown]
# # import basic library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
sns.set()

def display(w=16, h=5, dpi=200):
    plt.figure(figsize=(w, h), dpi=dpi)

# %% [markdown]
# # load data

# %%
data = pd.read_csv('IndexE8.csv')
data.head()
# Out:
#          date     spx      dax     ftse    nikkei
# 0  07/01/1994  469.90  2224.95  3445.98  18124.01
# 1  10/01/1994  475.27  2225.00  3440.58  18443.44
# 2  11/01/1994  474.13  2228.10  3413.77  18485.25
# 3  12/01/1994  474.17  2182.06  3372.02  18793.88
# 4  13/01/1994  472.47  2142.37  3360.01  18577.26

# %% [markdown]
# # examine data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6269 entries, 0 to 6268
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    6269 non-null   object
#  1   spx     6269 non-null   float64
#  2   dax     6269 non-null   float64
#  3   ftse    6269 non-null   float64
#  4   nikkei  6269 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 245.0+ KB

# %%
data.isna().sum()
# Out:
# date      0
# spx       0
# dax       0
# ftse      0
# nikkei    0
# dtype: int64

# %%
data.describe()
# Out:
#                spx           dax         ftse        nikkei
# count  6269.000000   6269.000000  6269.000000   6269.000000
# mean   1288.127542   6080.063363  5422.713545  14597.055700
# std     487.586473   2754.361032  1145.572428   4043.122953
# min     438.920000   1911.700000  2876.600000   7054.980000
# 25%     990.671905   4069.350000  4486.100000  10709.290000
# 50%    1233.420000   5773.340000  5662.430000  15028.170000
# 75%    1459.987747   7443.070000  6304.250000  17860.470000
# max    2872.867839  13559.600000  7778.637689  24124.150000

# %% [markdown]
# # visualize the data

# %%
display()
data.spx.plot()
data.ftse.plot()
plt.title('S&P vs FTSE price')
plt.ylabel('price')
plt.legend()
plt.show()

# %%
import scipy.stats as stat

# %%
display(w=16,h=16)
stat.probplot(data.spx, plot=plt)
plt.show()

# %% [markdown]
# # preprocessing data

# %%
data.date = pd.to_datetime(arg=data.date, dayfirst=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6269 entries, 0 to 6268
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    6269 non-null   datetime64[ns]
#  1   spx     6269 non-null   float64
#  2   dax     6269 non-null   float64
#  3   ftse    6269 non-null   float64
#  4   nikkei  6269 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 245.0 KB

# %%
data = data.set_index('date')
data.head()
# Out:
#                spx      dax     ftse    nikkei
# date
# 1994-01-07  469.90  2224.95  3445.98  18124.01
# 1994-01-10  475.27  2225.00  3440.58  18443.44
# 1994-01-11  474.13  2228.10  3413.77  18485.25
# 1994-01-12  474.17  2182.06  3372.02  18793.88
# 1994-01-13  472.47  2142.37  3360.01  18577.26

# %%
data = data.asfreq('b')
data.head()
# Out:
#                spx      dax     ftse    nikkei
# date
# 1994-01-07  469.90  2224.95  3445.98  18124.01
# 1994-01-10  475.27  2225.00  3440.58  18443.44
# 1994-01-11  474.13  2228.10  3413.77  18485.25
# 1994-01-12  474.17  2182.06  3372.02  18793.88
# 1994-01-13  472.47  2142.37  3360.01  18577.26

# %%
data.isna().sum()
# Out:
# spx       8
# dax       8
# ftse      8
# nikkei    8
# dtype: int64

# %%
data.spx = data.spx.fillna(method='ffill')
data.spx.isna().sum()
# Out:
# 0

# %%
data.ftse = data.ftse.fillna(method='bfill')
data.ftse.isna().sum()
# Out:
# 0

# %%
data.dax = data.dax.fillna(value=data.dax.mean())
data.dax.isna().sum()
# Out:
# 0

# %%
data['market_value'] = data.ftse
data.head()
# Out:
#                spx      dax     ftse    nikkei  market_value
# date
# 1994-01-07  469.90  2224.95  3445.98  18124.01       3445.98
# 1994-01-10  475.27  2225.00  3440.58  18443.44       3440.58
# 1994-01-11  474.13  2228.10  3413.77  18485.25       3413.77
# 1994-01-12  474.17  2182.06  3372.02  18793.88       3372.02
# 1994-01-13  472.47  2142.37  3360.01  18577.26       3360.01

# %%
del data['spx'], data['dax'], data['ftse'], data['nikkei']

# %%
data.head()
# Out:
#             market_value
# date
# 1994-01-07       3445.98
# 1994-01-10       3440.58
# 1994-01-11       3413.77
# 1994-01-12       3372.02
# 1994-01-13       3360.01

# %% [markdown]
# # splitting data

# %%
point = int(len(data)*0.8)
point
# Out:
# 5021

# %%
data_train = data.iloc[:point]
data_test = data.iloc[point:]
data_train.shape, data_test.shape
# Out:
# ((5021, 1), (1256, 1))

# %%
display()
plt.plot(data.market_value)
plt.axvline(x=data.index[point], color='yellow')
plt.show()

# %% [markdown]
# # white noise

# %%
white_noise = np.random.normal(loc=data_train.market_value.mean(), 
                               scale=data_train.market_value.std(),
                               size=len(data_train))

# %%
data_train['white_noise'] = white_noise
data_train.head()
# Out:
# C:\Users\yandiher\AppData\Local\Temp\ipykernel_9996\917661762.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train['white_noise'] = white_noise
#             market_value  white_noise
# date
# 1994-01-07       3445.98  2666.801871
# 1994-01-10       3440.58  3324.054809
# 1994-01-11       3413.77  6451.955696
# 1994-01-12       3372.02  5856.699491
# 1994-01-13       3360.01  4867.489595

# %%
display()
data_train.white_noise.plot()
data_train.market_value.plot()
plt.legend()
plt.show()

# %% [markdown]
# # random walk

# %%
random_walk = pd.read_csv('RandWalk.csv')
random_walk.head()
# Out:
#          date        price
# 0  07/01/1994  1122.139662
# 1  08/01/1994  1135.238562
# 2  09/01/1994  1109.897831
# 3  10/01/1994  1080.347860
# 4  11/01/1994  1082.095245

# %%
random_walk.date = pd.to_datetime(random_walk.date, dayfirst=True)
random_walk = random_walk.set_index('date')
random_walk = random_walk.asfreq('b')
random_walk.head()
# Out:
#                   price
# date
# 1994-01-07  1122.139662
# 1994-01-10  1080.347860
# 1994-01-11  1082.095245
# 1994-01-12  1083.639265
# 1994-01-13  1067.146255

# %%
random_walk.describe()
# Out:
#              price
# count  5021.000000
# mean   1269.944293
# std     444.216793
# min     585.483034
# 25%     931.550429
# 50%    1156.363045
# 75%    1488.362029
# max    2715.508720

# %%
data_train['random_walk'] = random_walk.price
data_train.head()
# Out:
# C:\Users\yandiher\AppData\Local\Temp\ipykernel_9996\3636145406.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train['random_walk'] = random_walk.price
#             market_value  white_noise  random_walk
# date
# 1994-01-07       3445.98  2666.801871  1122.139662
# 1994-01-10       3440.58  3324.054809  1080.347860
# 1994-01-11       3413.77  6451.955696  1082.095245
# 1994-01-12       3372.02  5856.699491  1083.639265
# 1994-01-13       3360.01  4867.489595  1067.146255

# %%
display()
data_train.random_walk.plot()
data_train.market_value.plot()
plt.legend()
plt.show()

# %% [markdown]
# # stationarity

# %%
import statsmodels.graphics.tsaplots as sgt
import statsmodels.tsa.stattools as sts
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
sts.adfuller(data_train.market_value)
# Out:
# (-1.904935638502626,
#  0.32974280493188823,
#  6,
#  5014,
#  {'1%': -3.4316548765428174,
#   '5%': -2.8621166146845334,
#   '10%': -2.5670769326348926},
#  54856.46568853504)

# %%
sts.adfuller(data_train.white_noise)
# Out:
# (-48.76499657396001,
#  0.0,
#  1,
#  5019,
#  {'1%': -3.4316535759402753,
#   '5%': -2.8621160400844468,
#   '10%': -2.567076626752987},
#  83187.70270469018)

# %%
sts.adfuller(data_train.random_walk)
# Out:
# (-1.3286073927689714,
#  0.6159849181617386,
#  24,
#  4996,
#  {'1%': -3.4316595802782865,
#   '5%': -2.8621186927706463,
#   '10%': -2.567078038881065},
#  46299.333497595144)

# %% [markdown]
# # seasonality

# %%
dec_additive = seasonal_decompose(data_train.market_value, model='additive')
dec_additive.plot()
plt.show()

# %%
dec_additive = seasonal_decompose(data_train.market_value, model='multiplicative')
dec_additive.plot()
plt.show()

# %% [markdown]
# # auto correlation function

# %%
sgt.plot_acf(data_train.market_value, lags=40, zero=False)
plt.ylim(-0.3, 1)
plt.show()

# %%
sgt.plot_acf(data_train.white_noise, lags=40, zero=False)
plt.ylim(-0.05, 0.05)
plt.show()

# %%
sgt.plot_acf(data_train.random_walk, lags=40, zero=False)
plt.ylim(-0.3, 1)
plt.show()

# %%
sgt.plot_pacf(data_train.market_value, lags=40, zero=False, method='ols')
plt.ylim(-0.1, 1)
plt.show()

# %%
sgt.plot_pacf(data_train.white_noise, lags=40, zero=False, method='ols')
plt.ylim(-0.05, 0.05)
plt.show()

# %% [markdown]
# # auto regression

# %%
from statsmodels.tsa.api import ARIMA
from scipy.stats.distributions import chi2

# %%
model_arima = ARIMA(data_train.market_value)

# %%
result = model_arima.fit()
print(result.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:           market_value   No. Observations:                 5021
# Model:                          ARIMA   Log Likelihood              -41893.031
# Date:                Sat, 06 May 2023   AIC                          83790.063
# Time:                        20:34:55   BIC                          83803.106
# Sample:                    01-07-1994   HQIC                         83794.633
#                          - 04-05-2013
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5089.7690     15.721    323.748      0.000    5058.956    5120.582
# sigma2      1.036e+06   3.11e+04     33.348      0.000    9.75e+05     1.1e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                5003.04   Jarque-Bera (JB):               329.83
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.40   Skew:                            -0.42
# Prob(H) (two-sided):                  0.00   Kurtosis:                         2.06
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
9.75e+05
# Out:
# 975000.0
